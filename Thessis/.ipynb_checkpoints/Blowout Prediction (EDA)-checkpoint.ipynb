# %% [markdown]
# # Warehouse Optimization

# %% [markdown]
# ## Initilization

# %%
import pandas as pd
import pandas_profiling
import numpy as np
data = pd.read_csv('ML_datafile.csv')
data.reset_index(drop=True, inplace=True)
data = data.drop(['Item No', 'Manufacturer No', 'Product Name', 'Date', 'STOCK TYPE', 'In Stock', 'List No',
                 'UPC Code', 'SaleRate','Blowout'], axis=1)
data.dtypes
data.head(10)
# Out:
#   Manufacturer            Category      Category Path 1  \
# 0   Supermicro         Power Cable            Component
# 1         ASUS        Bag & Sleeve          PC & Laptop
# 2          AMD              Others            Component
# 3         QNAP           DDR3 1333            Component
# 4   Supermicro           Accessory  Hardware & Software
# 5     SK hynix         Server DDR3            Component
# 6          APC     Battery Systems            Component
# 7   Supermicro  CPU on Board Combo            Component
# 8         ASUS   Speaker & Headset            Component
# 9         ASUS    Desktop Barebone            Component
#
#           Category Path 2     Category Path 3  Price(USD)  Cost price  \
# 0                   Cable         Power Cable       10.25      7.6875
# 1               Accessory        Bag & Sleeve        9.23      4.2300
# 2         CPU / Processor         Desktop CPU       76.88     57.6600
# 3             DRAM Memory       Notebook DRAM       76.88     57.6600
# 4    Server & Workstation           Accessory       92.76     69.5700
# 5             DRAM Memory         Server DRAM      186.55    139.9125
# 6  Power Protection / UPS     Battery Systems      263.94    197.9550
# 7             Motherboard  CPU on Board Combo      262.40    196.8000
# 8              Multimedia   Speaker & Headset      263.42    197.5650
# 9                Barebone    Desktop Barebone      480.72    360.5400
#
#    Inventory  Shipping    Profit  weight(lb)  SaleRateNew
# 0          1       2.5    0.0625        1.00          0.0
# 1          1       2.5    2.5000        0.50          0.0
# 2          1       2.5   16.7200        0.74          0.0
# 3          1       0.0   19.2200        0.10          0.0
# 4          1       2.5   20.6900        0.50          0.0
# 5          1       0.0   46.6375        0.08          0.0
# 6          1      10.0   55.9850       28.00          0.0
# 7          1       2.5   63.1000        5.00          0.0
# 8          1       2.5   63.3550        6.50          0.0
# 9          1       2.5  117.6800        0.50          0.0

# %% [markdown]
# ## Exploratory Analysis

# %%
# To get some basic ideas about the data
def summerize_data(df, columns):
    for column in columns:
        print(column)
        if df.dtypes[column] == np.object: # Categorical data
            print(df[column].value_counts())
        else:
            print(df[column].describe())
            
        print('\n')
    
columns = ["Price(USD)", "Inventory", "weight(lb)", "SaleRateNew"]
summerize_data(data, columns)
# Out:
# Price(USD)
# count    4200.000000
# mean      284.684874
# std       610.347111
# min         0.210000
# 25%        28.190000
# 50%        84.050000
# 75%       242.412500
# max      7021.250000
# Name: Price(USD), dtype: float64
#
#
# Inventory
# count    4200.000000
# mean       43.329524
# std        90.595148
# min         1.000000
# 25%         5.000000
# 50%        19.000000
# 75%        51.000000
# max      1002.000000
# Name: Inventory, dtype: float64
#
#
# weight(lb)
# count    4200.000000
# mean        6.472921
# std        13.758992
# min         0.000000
# 25%         0.350000
# 50%         1.545000
# 75%         5.490000
# max       174.000000
# Name: weight(lb), dtype: float64
#
#
# SaleRateNew
# count    4200.000000
# mean        0.913433
# std         1.138135
# min         0.000000
# 25%         0.125000
# 50%         0.772727
# 75%         1.181818
# max         8.644444
# Name: SaleRateNew, dtype: float64

# %% [markdown]
# # Missing Data Points Per Feature

# %%
data.isnull().sum()
# Out:
# Manufacturer         0
# Category             1
# Category Path 1      1
# Category Path 2      1
# Category Path 3    296
# Price(USD)           0
# Cost price           0
# Inventory            0
# Shipping             0
# Profit               0
# weight(lb)           0
# SaleRateNew          0
# dtype: int64

# %% [markdown]
# ## Graphs

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm 
import seaborn as sns; sns.set(color_codes=True)
# if using a Jupyter notebook, inlcude:
# %matplotlib inline

# %%
data["SaleRateNew"].plot.kde(bw_method=0.3)

# %%
sns.kdeplot(data["SaleRateNew"],bw=0.4, shade=True, color="r")

# %%
sns.kdeplot(data["SaleRateNew"], shade=True, color="r")

# %%
data["SaleRateNew"].plot.kde(bw_method=0.1)

# %%
sns.kdeplot(data["Price(USD)"],bw=0.4, shade=True, color="r")

# %%
data["Price(USD)"].plot.kde(bw_method=0.3)

# %%
data["Inventory"].plot.kde(bw_method=0.3)

# %%
sns.kdeplot(data["Inventory"],bw=0.4, shade=True, color="r")

# %%
data[ "weight(lb)"].plot.kde(bw_method=0.3)

# %%
sns.kdeplot(data["weight(lb)"],bw=0.4, shade=True, color="r")

# %% [markdown]
# ## corelation matrix

# %%
#correlation matrix
import seaborn as sns
corrmat = data.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);
corrmat
# Out:
#              Price(USD)  Cost price  Inventory  Shipping    Profit  \
# Price(USD)     1.000000    0.999997  -0.107053  0.417039  0.999871
# Cost price     0.999997    1.000000  -0.107122  0.417225  0.999845
# Inventory     -0.107053   -0.107122   1.000000 -0.110415 -0.105852
# Shipping       0.417039    0.417225  -0.110415  1.000000  0.404130
# Profit         0.999871    0.999845  -0.105852  0.404130  1.000000
# weight(lb)     0.523939    0.524002  -0.110241  0.791004  0.515159
# SaleRateNew   -0.117940   -0.117979   0.812032 -0.145811 -0.116367
#
#              weight(lb)  SaleRateNew
# Price(USD)     0.523939    -0.117940
# Cost price     0.524002    -0.117979
# Inventory     -0.110241     0.812032
# Shipping       0.791004    -0.145811
# Profit         0.515159    -0.116367
# weight(lb)     1.000000    -0.141525
# SaleRateNew   -0.141525     1.000000

# %% [markdown]
# # Relationship with categorical values

# %%
#box plot overallqual/saleprice
box_plot_df = data.sample(n=100, random_state=1)
var = 'Price(USD)'
box_plot_df = pd.concat([box_plot_df['SaleRateNew'], box_plot_df[var]], axis=1)
f, ax = plt.subplots(figsize=(20, 18))
fig = sns.boxplot(x=var, y="SaleRateNew", data=box_plot_df)
fig.axis(ymin=0, ymax=1);

# %%
#import pandas_profiling as pp

#check profile report of the dataset

#profile = data.profile_report(title='Pandas Profiling Report')
profile = pandas_profiling.ProfileReport(data)
profile.to_file("EDA.html")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas_profiling\describe.py:392: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
